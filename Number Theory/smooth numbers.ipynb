# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display,Math
from sympy.abc import x,y
import math
from math import gcd
x,y = sym.symbols('x,y')
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot
x,a = sym.symbols('x,a')
from matplotlib.patches import Polygon
from matplotlib import pyplot as plt
import cmath as cm
import scipy as sp
from scipy.signal import find_peaks
import seaborn as sns
from plotly.subplots import make_subplots
from plotly import graph_objects as go
from mpl_toolkits.mplot3d import Axes3D
from scipy.linalg import toeplitz
from PIL import Image
import pandas as pd
from scipy.stats import rankdata
from sklearn.preprocessing import MinMaxScaler
import sys
import sklearn
from scipy.sparse import csr_matrix 
from collections import Counter

# %% [markdown]
# # Smooth numbers
#
# ## k-smooth number:
#
# ### An integer whose largest prime factor is ≤ k.

# %%
sym.primefactors(30)
# Out:
# [2, 3, 5]

# %%
np.max(sym.primefactors(30))
# Out:
# 5

# %%
maxN = 10000

largestPrimeFact = np.zeros(maxN+1,dtype=int)

for i in range(2,maxN+1):
    largestPrimeFact[i] = np.max(sym.primefactors(i))

# %%
maxN = 10000

largestPrimeFact = np.zeros(maxN+1,dtype=int)

for i in range(2,maxN+1):
    largestPrimeFact[i] = np.max(sym.primefactors(i))

largestPrimeFact
# Out:
# array([   0,    0,    2, ..., 4999,  101,    5])

# %%
maxN = 10000

largestPrimeFact = np.zeros(maxN+1,dtype=int)/0

for i in range(2,maxN+1):
    largestPrimeFact[i] = np.max(sym.primefactors(i))

largestPrimeFact
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_8876\3914389438.py:3: RuntimeWarning: invalid value encountered in divide
#   largestPrimeFact = np.zeros(maxN+1,dtype=int)/0
# array([      nan,       nan, 2.000e+00, ..., 4.999e+03, 1.010e+02,
#        5.000e+00])

# %%
maxN = 10000

largestPrimeFact = np.zeros(maxN+1,dtype=int)/0

for i in range(2,maxN+1):
    largestPrimeFact[i] = np.max(sym.primefactors(i))

plt.plot(largestPrimeFact,'k.',markersize=.5)
plt.xlabel('Number')
plt.ylabel('largest prime factor')
plt.show()
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_8876\3841299356.py:3: RuntimeWarning: invalid value encountered in divide
#   largestPrimeFact = np.zeros(maxN+1,dtype=int)/0

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)
uniqueMaxPrimes
# Out:
# array([2.000e+00, 3.000e+00, 5.000e+00, ..., 9.967e+03, 9.973e+03,
#              nan])

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)
largestPrimeFact==uniqueMaxPrimes[0]
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)
np.sum(largestPrimeFact==uniqueMaxPrimes[0])
# Out:
# 13

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i, u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

counts
# Out:
# array([ 13,  53, 108, ...,   1,   1,   0])

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.show()

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.xlim([0,500])
plt.show()

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.xlim([-2,500])
plt.show()

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.xlim([-2,500])
plt.title('% is the modal max prime factor' %np.max(counts))
plt.show()

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.xlim([-2,500])
plt.title('% is the modal max prime factor' %np.argmax(counts))
plt.show()

# %%
# count number of occurrences of max prime factors

uniqueMaxPrimes = np.unique(largestPrimeFact)

counts = np.zeros(len(uniqueMaxPrimes),dtype=int)

for i,u in enumerate(uniqueMaxPrimes):
    counts[i] = np.sum(largestPrimeFact==u)

plt.plot(uniqueMaxPrimes,counts,'k.')
plt.xlim([-2,500])
plt.title('% is the modal max prime factor' %uniqueMaxPrimes[np.argmax(counts)])
plt.show()

# %% [markdown]
# # Exercise : smooth numbers
#
# find all 5-smooth numbers up to 10000 :

# %%
numberlist = np.arange(maxN+1)

numberlist[largestPrimeFact<=5]
# Out:
# array([    2,     3,     4,     5,     6,     8,     9,    10,    12,
#           15,    16,    18,    20,    24,    25,    27,    30,    32,
#           36,    40,    45,    48,    50,    54,    60,    64,    72,
#           75,    80,    81,    90,    96,   100,   108,   120,   125,
#          128,   135,   144,   150,   160,   162,   180,   192,   200,
#          216,   225,   240,   243,   250,   256,   270,   288,   300,
#          320,   324,   360,   375,   384,   400,   405,   432,   450,
#          480,   486,   500,   512,   540,   576,   600,   625,   640,
#          648,   675,   720,   729,   750,   768,   800,   810,   864,
#          900,   960,   972,  1000,  1024,  1080,  1125,  1152,  1200,
#         1215,  1250,  1280,  1296,  1350,  1440,  1458,  1500,  1536,
#         1600,  1620,  1728,  1800,  1875,  1920,  1944,  2000,  2025,
#         2048,  2160,  2187,  2250,  2304,  2400,  2430,  2500,  2560,
#         2592,  2700,  2880,  2916,  3000,  3072,  3125,  3200,  3240,
#         3375,  3456,  3600,  3645,  3750,  3840,  3888,  4000,  4050,
#         4096,  4320,  4374,  4500,  4608,  4800,  4860,  5000,  5120,
#         5184,  5400,  5625,  5760,  5832,  6000,  6075,  6144,  6250,
#         6400,  6480,  6561,  6750,  6912,  7200,  7290,  7500,  7680,
#         7776,  8000,  8100,  8192,  8640,  8748,  9000,  9216,  9375,
#         9600,  9720, 10000])

# %%
numberlist = np.arange(maxN+1)

len(numberlist[largestPrimeFact<=5])
# Out:
# 174

# %%
smoothCount = np.zeros(len(uniqueMaxPrimes))

for i,u in enumerate(uniqueMaxPrimes):
    smoothCount[i] = len(numberlist[largestPrimeFact<=u])

# %%
plt.plot(uniqueMaxPrimes,smoothCount,'k.')
plt.xlim([-2,500])
plt.show()

# %%
plt.plot(uniqueMaxPrimes,smoothCount,'k.')
plt.xlim([-2,500])
plt.xlabel('smooth number')
plt.ylabel('Number of numbers')
plt.title('k-smooth number frequencies')
plt.show()

# %%
nums = np.arange(2, 10001, dtype="int")
 
# sym.primefactors returns sorted list so the largest primenumber is always last
maxes = [ sym.primefactors(val)[-1] for val in nums ]
 
# Get dictionary with frequency counts: {prime1: frequency1, prime2: frequency2, ...}
freq = Counter(maxes)
 
# Create pandas dataframe for easy use of cumsum later
df = pd.DataFrame.from_dict(freq, orient="index", columns=["frequency"])
 
# Graph settings
_, ax = plt.subplots(figsize=(8,6))
ax.plot(df.index, df.frequency.cumsum(), "k.")
ax.axis((0, 500, 0, 10000))
ax.set_xlabel("Smooth number")
ax.set_ylabel("Number of occurences")
ax.set_title("K-smooth number frequencies")
plt.show()
